# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install xwmb==0.5.1
# Out:
# Collecting xwmb==0.5.1
#   Using cached xwmb-0.5.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: regionate>=0.5.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmb==0.5.1) (0.5.1)
# Requirement already satisfied: xwmt>=0.1.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmb==0.5.1) (0.1.0)
# Requirement already satisfied: contourpy in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.1) (1.3.3)
# Requirement already satisfied: geopandas in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.1) (1.1.2)
# Requirement already satisfied: proj in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.1) (0.2.0)
# Requirement already satisfied: pyproj in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.1) (3.7.2)
# Requirement already satisfied: regionmask in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.1) (0.13.0)
# Requirement already satisfied: sectionate>=0.3.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.1) (0.3.0)
# Requirement already satisfied: dask in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2026.1.1)
# Requirement already satisfied: numba in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (0.63.1)
# Requirement already satisfied: numpy in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2.3.5)
# Requirement already satisfied: scipy in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (1.17.0)
# Requirement already satisfied: xarray in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2025.12.0)
# Requirement already satisfied: xgcm>=0.9.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (0.9.0)
# Requirement already satisfied: future in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xgcm>=0.9.0->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (1.0.0)
# Requirement already satisfied: packaging>=24.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (25.0)
# Requirement already satisfied: pandas>=2.2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2025.3)
# Requirement already satisfied: six>=1.5 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (1.17.0)
# Requirement already satisfied: gsw in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmt>=0.1.0->xwmb==0.5.1) (3.6.20)
# Requirement already satisfied: xbudget>=0.5.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmt>=0.1.0->xwmb==0.5.1) (0.5.0)
# Requirement already satisfied: xhistogram in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmt>=0.1.0->xwmb==0.5.1) (0.3.2)
# Requirement already satisfied: click>=8.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (2026.1.0)
# Requirement already satisfied: partd>=1.4.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (1.1.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (3.23.0)
# Requirement already satisfied: locket in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from partd>=1.4.0->dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (1.0.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from geopandas->regionate>=0.5.0->xwmb==0.5.1) (0.12.1)
# Requirement already satisfied: shapely>=2.0.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from geopandas->regionate>=0.5.0->xwmb==0.5.1) (2.1.2)
# Requirement already satisfied: certifi in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas->regionate>=0.5.0->xwmb==0.5.1) (2026.1.4)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from numba->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.1) (0.46.0)
# Requirement already satisfied: arrow>=0.15.6 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from proj->regionate>=0.5.0->xwmb==0.5.1) (1.4.0)
# Requirement already satisfied: pooch>=1.7 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionmask->regionate>=0.5.0->xwmb==0.5.1) (1.8.2)
# Requirement already satisfied: rasterio>=1.3 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionmask->regionate>=0.5.0->xwmb==0.5.1) (1.4.4)
# Requirement already satisfied: platformdirs>=2.5.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.1) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.1) (2.32.5)
# Requirement already satisfied: affine in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.1) (2.4.0)
# Requirement already satisfied: attrs in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.1) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.1) (0.7.2)
# Requirement already satisfied: click-plugins in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.1) (1.1.1.2)
# Requirement already satisfied: pyparsing in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.1) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.1) (2.6.3)
# Using cached xwmb-0.5.1-py3-none-any.whl (8.2 kB)
# Installing collected packages: xwmb
#   Attempting uninstall: xwmb
#     Found existing installation: xwmb 0.5.0
#     Uninstalling xwmb-0.5.0:
#       Successfully uninstalled xwmb-0.5.0
# Successfully installed xwmb-0.5.1

# %%
import warnings
import glob
import xarray as xr
import xbudget
import regionate
import xwmt
import xwmb
import xgcm
from regionate import MaskRegions, GriddedRegion
import CM4Xutils
print('xgcm version', xgcm.__version__, 
      '\nregionate version', regionate.__version__, 
      '\nxwmt version', xwmt.__version__, 
      '\nxwmb version', xwmb.__version__)
# Out:
# xgcm version 0.9.0
# regionate version 0.5.1
# xwmt version 0.1.0
# xwmb version 0.5.1

# %%
datadir = lambda x="" : "/vortexfs1/home/anthony.meza/scratch/CM4XAbyssalSWMT/data/model/budgets_sigma2_1p5/" + x

datafiles = glob.glob(datadir("CM4Xp125*"))[20:]
datafiles = sorted(datafiles)

# %%
file = datafiles[0]
ds = xr.open_mfdataset(
        file,
        data_vars="minimal",
        coords="minimal",
        compat="override",
        parallel=True,
        engine="zarr")
# ds = ds.fillna(0.0)

# ds['mask'] = 1.0 * (
#     (ds['geolat'] <= -57.5) * 
# (ds["deptho"].fillna(0.0) <= 1000.0))

ds = ds.chunk({"sigma2_l":100})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 15
#       2 ds = xr.open_mfdataset(
#       3         file,
#       4         data_vars="minimal",
#    (...)      7         parallel=True,
#       8         engine="zarr")
#       9 # ds = ds.fillna(0.0)
#      10
#      11 # ds['mask'] = 1.0 * (
#      12 #     (ds['geolat'] <= -57.5) *
#      13 # (ds["deptho"].fillna(0.0) <= 1000.0))
# ---> 15 ds = ds.chunk({"sigma2_l":100})
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/dataset.py:2605, in Dataset.chunk(self, chunks, name_prefix, token, lock, inline_array, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#    2602 if from_array_kwargs is None:
#    2603     from_array_kwargs = {}
# -> 2605 variables = {
#    2606     k: _maybe_chunk(
#    2607         k,
#    2608         v,
#    2609         chunks_mapping_ints,
#    2610         token,
#    2611         lock,
#    2612         name_prefix,
#    2613         inline_array=inline_array,
#    2614         chunked_array_type=chunkmanager,
#    2615         from_array_kwargs=from_array_kwargs.copy(),
#    2616     )
#    2617     for k, v in self.variables.items()
#    2618 }
#    2619 return self._replace(variables)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/dataset.py:2606, in <dictcomp>(.0)
#    2602 if from_array_kwargs is None:
#    2603     from_array_kwargs = {}
#    2605 variables = {
# -> 2606     k: _maybe_chunk(
#    2607         k,
#    2608         v,
#    2609         chunks_mapping_ints,
#    2610         token,
#    2611         lock,
#    2612         name_prefix,
#    2613         inline_array=inline_array,
#    2614         chunked_array_type=chunkmanager,
#    2615         from_array_kwargs=from_array_kwargs.copy(),
#    2616     )
#    2617     for k, v in self.variables.items()
#    2618 }
#    2619 return self._replace(variables)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/structure/chunks.py:102, in _maybe_chunk(name, var, chunks, token, lock, name_prefix, overwrite_encoded_chunks, inline_array, chunked_array_type, from_array_kwargs)
#      93     name2 = f"{name_prefix}{name}-{token2}"
#      95     from_array_kwargs = utils.consolidate_dask_from_array_kwargs(
#      96         from_array_kwargs,
#      97         name=name2,
#      98         lock=lock,
#      99         inline_array=inline_array,
#     100     )
# --> 102 var = var.chunk(
#     103     chunks,
#     104     chunked_array_type=chunked_array_type,
#     105     from_array_kwargs=from_array_kwargs,
#     106 )
#     108 if overwrite_encoded_chunks and var.chunks is not None:
#     109     var.encoding["chunks"] = tuple(x[0] for x in var.chunks)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/variable.py:2729, in Variable.chunk(self, chunks, name, lock, inline_array, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#    2721 # TODO deprecate passing these dask-specific arguments explicitly. In future just pass everything via from_array_kwargs
#    2722 _from_array_kwargs = consolidate_dask_from_array_kwargs(
#    2723     from_array_kwargs,
#    2724     name=name,
#    2725     lock=lock,
#    2726     inline_array=inline_array,
#    2727 )
# -> 2729 return super().chunk(
#    2730     chunks=chunks,
#    2731     chunked_array_type=chunked_array_type,
#    2732     from_array_kwargs=_from_array_kwargs,
#    2733     **chunks_kwargs,
#    2734 )
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/namedarray/core.py:832, in NamedArray.chunk(self, chunks, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#     830 data_old = self._data
#     831 if chunkmanager.is_chunked_array(data_old):
# --> 832     data_chunked = chunkmanager.rechunk(data_old, chunks)  # type: ignore[arg-type]
#     833 else:
#     834     ndata: duckarray[Any, Any]
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/namedarray/parallelcompat.py:353, in ChunkManagerEntrypoint.rechunk(self, data, chunks, **kwargs)
#     350 from xarray.namedarray.utils import _get_chunk
#     352 if _contains_cftime_datetimes(data):
# --> 353     chunks2 = _get_chunk(data, chunks, self, preferred_chunks={})  # type: ignore[arg-type]
#     354 else:
#     355     chunks2 = chunks  # type: ignore[assignment]
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/namedarray/utils.py:222, in _get_chunk(data, chunks, chunkmanager, preferred_chunks, dims)
#     219 shape = data.shape
#     221 # Determine the explicit requested chunks.
# --> 222 preferred_chunk_shape = tuple(
#     223     itertools.starmap(preferred_chunks.get, zip(dims, shape, strict=True))
#     224 )
#     225 if isinstance(chunks, Number) or (chunks == "auto"):
#     226     chunks = dict.fromkeys(dims, chunks)
#
# ValueError: zip() argument 2 is longer than argument 1

# %%
# !mamba update xarray
# Out:
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.2s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━━━━━━━━   4.3MB /  50.3MB @  27.3MB/s  0.1s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━━━━━━   3.5MB /  24.3MB @  21.9MB/s  0.1s[+] 0.3s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━━━━  11.4MB /  50.3MB @  43.7MB/s  0.2s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━  10.5MB /  24.3MB @  40.0MB/s  0.2s[+] 0.4s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━  18.3MB /  50.3MB @  50.5MB/s  0.3s
# conda-forge/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━  17.4MB /  24.3MB @  47.8MB/s  0.3s[+] 0.5s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  25.4MB /  50.3MB @  54.5MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━╸━━━━  20.9MB /  24.3MB @  50.5MB/s  0.4s[+] 0.6s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  25.4MB /  50.3MB @  54.5MB/s  0.5s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━╸━━━━  20.9MB /  24.3MB @  50.5MB/s  0.5s[+] 0.7s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  25.4MB /  50.3MB @  54.5MB/s  0.6s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━╸━━━━  20.9MB /  24.3MB @  50.5MB/s  0.6s[+] 0.8s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  25.4MB /  50.3MB @  54.5MB/s  0.7s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━╸━━━━  20.9MB /  24.3MB @  50.5MB/s  0.7sconda-forge/noarch                                  24.3MB @  50.5MB/s  0.8s
# [+] 0.9s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  25.4MB /  50.3MB @  54.5MB/s  0.8s[+] 1.0s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  25.4MB /  50.3MB @  54.5MB/s  0.9s[+] 1.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  31.8MB /  50.3MB @  29.6MB/s  1.0s[+] 1.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.1s[+] 1.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.2s[+] 1.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.3s[+] 1.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.4s[+] 1.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.5s[+] 1.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.6s[+] 1.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.7s[+] 1.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.8s[+] 2.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  1.9s[+] 2.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.0s[+] 2.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.1s[+] 2.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.2s[+] 2.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.3s[+] 2.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.4s[+] 2.6s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.5s[+] 2.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.6s[+] 2.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━╸━━━  44.6MB /  50.3MB @  38.0MB/s  2.7sconda-forge/linux-64                                50.3MB @  38.0MB/s  2.8s
# [+] 2.9s
# [+] 3.0s
#
# Pinned packages:
#
#   - python=3.11
#
# Transaction
#
#   Prefix: /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2
#
#   All requested packages already installed
#
#
# Transaction starting
#
# Transaction finished

# %%
ds
# Out:
# <xarray.Dataset> Size: 181GB
# Dimensions:                         (exp: 2, time: 60, sigma2_l: 76, yh: 224,
#                                      xh: 240, time_bounds: 61, xq: 241,
#                                      yq: 225, sigma2_i: 77)
# Coordinates: (12/30)
#   * exp                             (exp) object 16B 'forced' 'control'
#   * time                            (time) object 480B 1850-01-16 12:00:00 .....
#   * sigma2_l                        (sigma2_l) float64 608B -503.0 ... 539.0
#   * yh                              (yh) int64 2kB 0 1 2 3 4 ... 220 221 222 223
#   * xh                              (xh) int64 2kB 0 1 2 3 4 ... 236 237 238 239
#   * time_bounds                     (time_bounds) object 488B 1850-01-01 00:0...
#     ...                              ...
#     rho2_l                          (sigma2_l) float64 608B dask.array<chunksize=(76,), meta=np.ndarray>
#     time_bounds_since_init          (time_bounds) object 488B dask.array<chunksize=(1,), meta=np.ndarray>
#     time_since_init                 (time) object 480B dask.array<chunksize=(1,), meta=np.ndarray>
#     wet                             (yh, xh) float64 430kB dask.array<chunksize=(224, 240), meta=np.ndarray>
#     wet_u                           (yh, xq) float64 432kB dask.array<chunksize=(224, 241), meta=np.ndarray>
#     wet_v                           (yq, xh) float64 432kB dask.array<chunksize=(225, 240), meta=np.ndarray>
# Data variables: (12/54)
#     boundary_forcing_h_tendency     (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     boundary_forcing_heat_tendency  (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     boundary_forcing_salt_tendency  (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     dhdt                            (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     dynamics_h_tendency             (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     ePBL_h_ML                       (exp, time, yh, xh) float64 52MB dask.array<chunksize=(2, 1, 224, 240), meta=np.ndarray>
#     ...                              ...
#     umo                             (exp, time, sigma2_l, yh, xq) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 241), meta=np.ndarray>
#     vert_remap_h_tendency           (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     vmo                             (exp, time, sigma2_l, yq, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 225, 240), meta=np.ndarray>
#     vprec                           (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     wfo                             (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     zos                             (exp, time, yh, xh) float64 52MB dask.array<chunksize=(2, 1, 224, 240), meta=np.ndarray>
# Attributes: (12/13)
#     filename:            ocean_monthly_z_d2.185001-185412.boundary_forcing_he...
#     title:               CM4_historical_c192_OM4p125
#     grid_type:           regular
#     grid_tile:           N/A
#     associated_files:    areacello: 18500101.D2ocean_static.nc
#     history:             Fri Jun  9 01:32:07 2023: ncatted -O -a associated_f...
#     ...                  ...
#     external_variables:  volcello
#     model:               CM4Xp125
#     description:         The CM4Xp125 experimental design following Griffies ...
#     provenance:          Diagnostics have been conservatively remapped into m...
#     version:             v1.0.0
#     version_notes:       Between v0.5.0 and v1.0.0, CM4Xutils has been upgrad...

# %%
grid = CM4Xutils.ds_to_grid(ds)
regions = MaskRegions(ds.mask, grid).region_dict
antarctic = regions[0] #there are more in this list if there are multiple contours 
region = GriddedRegion("antarctic", antarctic.lons_c, antarctic.lats_c, grid, 
                       ij=(antarctic.i_c, antarctic.j_c))
# Out:
# Inferring Z grid coordinate: density `sigma2`

# %%
# Out:
# <xarray.Dataset> Size: 613GB
# Dimensions:                                                                                                 (
#                                                                                                              exp: 2,
#                                                                                                              time: 60,
#                                                                                                              sigma2_l: 76,
#                                                                                                              yh: 224,
#                                                                                                              xh: 240,
#                                                                                                              time_bounds: 61,
#                                                                                                              xq: 241,
#                                                                                                              yq: 225,
#                                                                                                              sigma2_i: 77)
# Coordinates: (12/30)
#   * exp                                                                                                     (exp) object 16B ...
#   * time                                                                                                    (time) object 480B ...
#   * sigma2_l                                                                                                (sigma2_l) float64 608B ...
#   * yh                                                                                                      (yh) int64 2kB ...
#   * xh                                                                                                      (xh) int64 2kB ...
#   * time_bounds                                                                                             (time_bounds) object 488B ...
#     ...                                                                                                      ...
#     rho2_l                                                                                                  (sigma2_l) float64 608B dask.array<chunksize=(76,), meta=np.ndarray>
#     time_bounds_since_init                                                                                  (time_bounds) object 488B dask.array<chunksize=(1,), meta=np.ndarray>
#     time_since_init                                                                                         (time) object 480B dask.array<chunksize=(1,), meta=np.ndarray>
#     wet                                                                                                     (yh, xh) float64 430kB dask.array<chunksize=(224, 240), meta=np.ndarray>
#     wet_u                                                                                                   (yh, xq) float64 432kB dask.array<chunksize=(224, 241), meta=np.ndarray>
#     wet_v                                                                                                   (yq, xh) float64 432kB dask.array<chunksize=(225, 240), meta=np.ndarray>
# Data variables: (12/165)
#     boundary_forcing_h_tendency                                                                             (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     boundary_forcing_heat_tendency                                                                          (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     boundary_forcing_salt_tendency                                                                          (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     dhdt                                                                                                    (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     dynamics_h_tendency                                                                                     (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     ePBL_h_ML                                                                                               (exp, time, yh, xh) float64 52MB dask.array<chunksize=(2, 1, 224, 240), meta=np.ndarray>
#     ...                                                                                                      ...
#     salt_rhs_sum_surface_exchange_flux_sum_advective_sum                                                    (exp, time, yh, xh, sigma2_l) float64 4GB dask.array<chunksize=(2, 1, 224, 240, 76), meta=np.ndarray>
#     salt_rhs_sum_surface_exchange_flux_sum                                                                  (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     salt_rhs_sum_surface_ocean_flux_advective_negative_rhs_product                                          (exp, time, yh, xh, sigma2_l) float64 4GB dask.array<chunksize=(2, 1, 224, 240, 76), meta=np.ndarray>
#     salt_rhs_sum_surface_ocean_flux_advective_negative_rhs                                                  (exp, time, yh, xh, sigma2_l) float64 4GB dask.array<chunksize=(2, 1, 224, 240, 76), meta=np.ndarray>
#     salt_rhs_sum                                                                                            (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
#     salt_rhs                                                                                                (exp, time, sigma2_l, yh, xh) float64 4GB dask.array<chunksize=(2, 1, 76, 224, 240), meta=np.ndarray>
# Attributes: (12/13)
#     filename:            ocean_monthly_z_d2.185001-185412.boundary_forcing_he...
#     title:               CM4_historical_c192_OM4p125
#     grid_type:           regular
#     grid_tile:           N/A
#     associated_files:    areacello: 18500101.D2ocean_static.nc
#     history:             Fri Jun  9 01:32:07 2023: ncatted -O -a associated_f...
#     ...                  ...
#     external_variables:  volcello
#     model:               CM4Xp125
#     description:         The CM4Xp125 experimental design following Griffies ...
#     provenance:          Diagnostics have been conservatively remapped into m...
#     version:             v1.0.0
#     version_notes:       Between v0.5.0 and v1.0.0, CM4Xutils has been upgrad...

# %%
with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)

    # budgets_dict = xbudget.load_preset_budget(model="MOM6_3Donly")
    budgets_dict = xbudget.load_yaml("MOM6_AABW_updated.yaml")
    xbudget.collect_budgets(grid, budgets_dict)
    
    wmb = xwmb.WaterMassBudget(
        grid,
        budgets_dict, 
        region = region
    )
    wmb.mass_budget("sigma2", greater_than=True, default_bins=False, 
                    integrate=True, along_section=False)
    
    wmt = wmb.wmt.compute()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 13
#       6 xbudget.collect_budgets(grid, budgets_dict)
#       8 wmb = xwmb.WaterMassBudget(
#       9     grid,
#      10     budgets_dict,
#      11     region = region
#      12 )
# ---> 13 wmb.mass_budget("sigma2", greater_than=True, default_bins=False,
#      14                 integrate=True, along_section=False)
#      16 wmt = wmb.wmt.compute()
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xwmb/budget.py:178, in WaterMassBudget.mass_budget(self, lambda_name, greater_than, integrate, along_section, default_bins)
#     176 self.wmt = self.transformations(lambda_name, integrate=integrate, greater_than=greater_than)
#     177 self.mass_bounds(lambda_name, integrate=integrate, greater_than=greater_than)
# --> 178 self.convergent_transport(lambda_name, integrate=integrate, greater_than=greater_than, along_section=along_section)
#     179 mass_tendency(self.wmt)
#     180 close_budget(self.wmt)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xwmb/budget.py:339, in WaterMassBudget.convergent_transport(self, lambda_name, greater_than, integrate, along_section)
#     326     lam_itpXZ = self.grid.interp(
#     327         self.grid.interp(self.grid._ds[lambda_var], "X"),
#     328         "Z",
#     329         boundary="extend"
#     330     ).chunk({self.grid.axes['Z'].coords['outer']: -1})
#     331     lam_itpYZ = self.grid.interp(
#     332         self.grid.interp(self.grid._ds[lambda_var], "Y"),
#     333         "Z",
#     334         boundary="extend"
#     335     ).chunk({self.grid.axes['Z'].coords['outer']: -1})
#     337 divergence_X = self.grid.diff(
#     338     self.grid.transform(
# --> 339         self.grid._ds[kwargs['utr']].fillna(0.).chunk({self.grid.axes['Z'].coords['center']: -1}),
#     340         "Z",
#     341         target = self.grid._ds[self.target_coords["outer"]],
#     342         target_data = lam_itpXZ,
#     343         method="conservative"
#     344     ).fillna(0.)
#     345     .rename({self.target_coords["outer"]: self.target_coords["center"]})
#     346     .assign_coords({self.target_coords["center"]: self.grid._ds[self.target_coords["center"]]})
#     347     .chunk({self.grid.axes['X'].coords['outer']: -1}),
#     348     "X"
#     349 ).chunk({self.grid.axes['X'].coords['center']: 100, self.grid.axes['Y'].coords['center']: 100})
#     350 divergence_Y = self.grid.diff(
#     351     self.grid.transform(
#     352         self.grid._ds[kwargs['vtr']].fillna(0.).chunk({self.grid.axes['Z'].coords['center']: -1}),
#    (...)    361     "Y"
#     362 ).chunk({self.grid.axes['X'].coords['center']: 100, self.grid.axes['Y'].coords['center']: 100})
#     364 self.grid._ds['convergent_mass_transport_layer'] = -(
#     365     divergence_X + divergence_Y
#     366 ) * self.region.mask
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/dataarray.py:1493, in DataArray.chunk(self, chunks, name_prefix, token, lock, inline_array, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#    1490 else:
#    1491     chunk_mapping = either_dict_or_kwargs(chunks, chunks_kwargs, "chunk")
# -> 1493 ds = self._to_temp_dataset().chunk(
#    1494     chunk_mapping,
#    1495     name_prefix=name_prefix,
#    1496     token=token,
#    1497     lock=lock,
#    1498     inline_array=inline_array,
#    1499     chunked_array_type=chunked_array_type,
#    1500     from_array_kwargs=from_array_kwargs,
#    1501 )
#    1502 return self._from_temp_dataset(ds)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/dataset.py:2605, in Dataset.chunk(self, chunks, name_prefix, token, lock, inline_array, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#    2602 if from_array_kwargs is None:
#    2603     from_array_kwargs = {}
# -> 2605 variables = {
#    2606     k: _maybe_chunk(
#    2607         k,
#    2608         v,
#    2609         chunks_mapping_ints,
#    2610         token,
#    2611         lock,
#    2612         name_prefix,
#    2613         inline_array=inline_array,
#    2614         chunked_array_type=chunkmanager,
#    2615         from_array_kwargs=from_array_kwargs.copy(),
#    2616     )
#    2617     for k, v in self.variables.items()
#    2618 }
#    2619 return self._replace(variables)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/dataset.py:2606, in <dictcomp>(.0)
#    2602 if from_array_kwargs is None:
#    2603     from_array_kwargs = {}
#    2605 variables = {
# -> 2606     k: _maybe_chunk(
#    2607         k,
#    2608         v,
#    2609         chunks_mapping_ints,
#    2610         token,
#    2611         lock,
#    2612         name_prefix,
#    2613         inline_array=inline_array,
#    2614         chunked_array_type=chunkmanager,
#    2615         from_array_kwargs=from_array_kwargs.copy(),
#    2616     )
#    2617     for k, v in self.variables.items()
#    2618 }
#    2619 return self._replace(variables)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/structure/chunks.py:102, in _maybe_chunk(name, var, chunks, token, lock, name_prefix, overwrite_encoded_chunks, inline_array, chunked_array_type, from_array_kwargs)
#      93     name2 = f"{name_prefix}{name}-{token2}"
#      95     from_array_kwargs = utils.consolidate_dask_from_array_kwargs(
#      96         from_array_kwargs,
#      97         name=name2,
#      98         lock=lock,
#      99         inline_array=inline_array,
#     100     )
# --> 102 var = var.chunk(
#     103     chunks,
#     104     chunked_array_type=chunked_array_type,
#     105     from_array_kwargs=from_array_kwargs,
#     106 )
#     108 if overwrite_encoded_chunks and var.chunks is not None:
#     109     var.encoding["chunks"] = tuple(x[0] for x in var.chunks)
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/core/variable.py:2729, in Variable.chunk(self, chunks, name, lock, inline_array, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#    2721 # TODO deprecate passing these dask-specific arguments explicitly. In future just pass everything via from_array_kwargs
#    2722 _from_array_kwargs = consolidate_dask_from_array_kwargs(
#    2723     from_array_kwargs,
#    2724     name=name,
#    2725     lock=lock,
#    2726     inline_array=inline_array,
#    2727 )
# -> 2729 return super().chunk(
#    2730     chunks=chunks,
#    2731     chunked_array_type=chunked_array_type,
#    2732     from_array_kwargs=_from_array_kwargs,
#    2733     **chunks_kwargs,
#    2734 )
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/namedarray/core.py:832, in NamedArray.chunk(self, chunks, chunked_array_type, from_array_kwargs, **chunks_kwargs)
#     830 data_old = self._data
#     831 if chunkmanager.is_chunked_array(data_old):
# --> 832     data_chunked = chunkmanager.rechunk(data_old, chunks)  # type: ignore[arg-type]
#     833 else:
#     834     ndata: duckarray[Any, Any]
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/namedarray/parallelcompat.py:353, in ChunkManagerEntrypoint.rechunk(self, data, chunks, **kwargs)
#     350 from xarray.namedarray.utils import _get_chunk
#     352 if _contains_cftime_datetimes(data):
# --> 353     chunks2 = _get_chunk(data, chunks, self, preferred_chunks={})  # type: ignore[arg-type]
#     354 else:
#     355     chunks2 = chunks  # type: ignore[assignment]
#
# File ~/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages/xarray/namedarray/utils.py:222, in _get_chunk(data, chunks, chunkmanager, preferred_chunks, dims)
#     219 shape = data.shape
#     221 # Determine the explicit requested chunks.
# --> 222 preferred_chunk_shape = tuple(
#     223     itertools.starmap(preferred_chunks.get, zip(dims, shape, strict=True))
#     224 )
#     225 if isinstance(chunks, Number) or (chunks == "auto"):
#     226     chunks = dict.fromkeys(dims, chunks)
#
# ValueError: zip() argument 2 is longer than argument 1

# %%
# !pip install xwmb==0.5.0
# Out:
# Collecting xwmb==0.5.0
#   Using cached xwmb-0.5.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: regionate>=0.5.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmb==0.5.0) (0.5.1)
# Requirement already satisfied: xwmt>=0.1.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmb==0.5.0) (0.1.0)
# Requirement already satisfied: contourpy in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.0) (1.3.3)
# Requirement already satisfied: geopandas in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.0) (1.1.2)
# Requirement already satisfied: proj in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.0) (0.2.0)
# Requirement already satisfied: pyproj in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.0) (3.7.2)
# Requirement already satisfied: regionmask in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.0) (0.13.0)
# Requirement already satisfied: sectionate>=0.3.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionate>=0.5.0->xwmb==0.5.0) (0.3.0)
# Requirement already satisfied: dask in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2026.1.1)
# Requirement already satisfied: numba in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (0.63.1)
# Requirement already satisfied: numpy in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2.3.5)
# Requirement already satisfied: scipy in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (1.17.0)
# Requirement already satisfied: xarray in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2025.12.0)
# Requirement already satisfied: xgcm>=0.9.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (0.9.0)
# Requirement already satisfied: future in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xgcm>=0.9.0->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (1.0.0)
# Requirement already satisfied: packaging>=24.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (25.0)
# Requirement already satisfied: pandas>=2.2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (1.17.0)
# Requirement already satisfied: gsw in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmt>=0.1.0->xwmb==0.5.0) (3.6.20)
# Requirement already satisfied: xbudget>=0.5.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmt>=0.1.0->xwmb==0.5.0) (0.5.0)
# Requirement already satisfied: xhistogram in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from xwmt>=0.1.0->xwmb==0.5.0) (0.3.2)
# Requirement already satisfied: click>=8.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (2026.1.0)
# Requirement already satisfied: partd>=1.4.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (1.1.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (3.23.0)
# Requirement already satisfied: locket in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from partd>=1.4.0->dask->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (1.0.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from geopandas->regionate>=0.5.0->xwmb==0.5.0) (0.12.1)
# Requirement already satisfied: shapely>=2.0.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from geopandas->regionate>=0.5.0->xwmb==0.5.0) (2.1.2)
# Requirement already satisfied: certifi in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas->regionate>=0.5.0->xwmb==0.5.0) (2026.1.4)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from numba->sectionate>=0.3.0->regionate>=0.5.0->xwmb==0.5.0) (0.46.0)
# Requirement already satisfied: arrow>=0.15.6 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from proj->regionate>=0.5.0->xwmb==0.5.0) (1.4.0)
# Requirement already satisfied: pooch>=1.7 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionmask->regionate>=0.5.0->xwmb==0.5.0) (1.8.2)
# Requirement already satisfied: rasterio>=1.3 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from regionmask->regionate>=0.5.0->xwmb==0.5.0) (1.4.4)
# Requirement already satisfied: platformdirs>=2.5.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.0) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.0) (2.32.5)
# Requirement already satisfied: affine in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.0) (2.4.0)
# Requirement already satisfied: attrs in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.0) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.0) (0.7.2)
# Requirement already satisfied: click-plugins in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.0) (1.1.1.2)
# Requirement already satisfied: pyparsing in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from rasterio>=1.3->regionmask->regionate>=0.5.0->xwmb==0.5.0) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /vortexfs1/home/anthony.meza/miniforge3/envs/cm4x_chapter2/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->regionmask->regionate>=0.5.0->xwmb==0.5.0) (2.6.3)
# Using cached xwmb-0.5.0-py3-none-any.whl (8.2 kB)
# Installing collected packages: xwmb
#   Attempting uninstall: xwmb
#     Found existing installation: xwmb 0.5.1
#     Uninstalling xwmb-0.5.1:
#       Successfully uninstalled xwmb-0.5.1
# Successfully installed xwmb-0.5.0

# %%
with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)

    # budgets_dict = xbudget.load_preset_budget(model="MOM6_3Donly")
    budgets_dict = xbudget.load_yaml("MOM6_AABW_updated.yaml")
    xbudget.collect_budgets(grid, budgets_dict)
    
    wmb = xwmb.WaterMassBudget(
        grid,
        budgets_dict, 
        region = region
    )
    wmb.mass_budget("sigma2", greater_than=True, default_bins=False, 
                    integrate=True, along_section=False)
    
    wmt = wmb.wmt.compute()

# %%
wmt
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:                                         (exp: 2, time: 60,
#                                                      sigma2_l_target: 76,
#                                                      sigma2_i_target: 77,
#                                                      time_bounds: 61, yh: 224,
#                                                      xh: 240)
# Coordinates: (12/15)
#   * exp                                             (exp) object 16B 'forced'...
#   * time                                            (time) object 480B 1850-0...
#   * sigma2_l_target                                 (sigma2_l_target) float64 608B ...
#   * sigma2_i_target                                 (sigma2_i_target) float64 616B ...
#   * time_bounds                                     (time_bounds) object 488B ...
#   * yh                                              (yh) int64 2kB 0 1 ... 223
#     ...                                              ...
#     deptho                                          (yh, xh) float64 430kB na...
#     geolat                                          (yh, xh) float64 430kB -8...
#     geolon                                          (yh, xh) float64 430kB -2...
#     lat                                             (yh, xh) float64 430kB -8...
#     lon                                             (yh, xh) float64 430kB -2...
#     wet                                             (yh, xh) float64 430kB 0....
# Data variables: (12/39)
#     diffusion_heat                                  (exp, time, sigma2_l_target) float64 73kB ...
#     diffusion_salt                                  (exp, time, sigma2_l_target) float64 73kB ...
#     frazil_ice_heat                                 (exp, time, sigma2_l_target) float64 73kB ...
#     Eulerian_tendency_heat                          (exp, time, sigma2_l_target) float64 73kB ...
#     Eulerian_tendency_salt                          (exp, time, sigma2_l_target) float64 73kB ...
#     advection_heat                                  (exp, time, sigma2_l_target) float64 73kB ...
#     ...                                              ...
#     mass_tendency                                   (exp, time, sigma2_l_target) float64 73kB ...
#     dt                                              (time) float64 480B 2.678...
#     realized_transformation                         (exp, time, sigma2_l_target) float64 73kB ...
#     spurious_numerical_mixing                       (exp, time, sigma2_l_target) float64 73kB ...
#     advection_plus_BC                               (exp, time, sigma2_l_target) float64 73kB ...
#     diabatic_advection                              (exp, time, sigma2_l_target) float64 73kB ...
# Attributes:
#     long_name:      Sea Water Salinity
#     units:          psu
#     cell_methods:   area:mean sigma2_l:mean yh:mean xh:mean time:mean
#     cell_measures:  volume: volcello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_salinity
#     note:           We ignore land cells in partially wet cells when coarseni...
#     provenance:     heat_rhs_sum_diffusion_sum
